# %% [markdown]
# ### Advent of Code 2021 | Day 2 | Part 1

# %%
import pandas as pd

# %%
df = pd.read_csv('input.txt', sep = '\n', names = ['commands'])

# %%
# horizontal, depth
coords = [0, 0]

for i, value in enumerate(df['commands']):
    value_explode = value.split(' ')
    
    # Move forward
    if value_explode[0] == 'forward':
        coords[0] = coords[0] + int(value_explode[1])
    # Dive deeper
    elif value_explode[0] == 'down':
        coords[1] = coords[1] + int(value_explode[1])
    # Ascend toward the surface
    else:
        coords[1] = coords[1] - int(value_explode[1])
        
print(f'Final Location - Final Horizontal Position: {coords[0]} | Final Depth: {coords[1]}')
print(f'Horizontal Position * Depth: {coords[0] * coords[1]}')
# Out:
# Final Location - Final Horizontal Position: 1957 | Final Depth: 955
# Horizontal Position * Depth: 1868935
